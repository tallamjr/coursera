% %%
ls
% Out:
% Untitled.ipynb	   ex2_reg.m	 mapFeature.m		 sigmoid.m
% costFunction.m	   ex2data1.txt  plotData.m		 submit.m
% costFunctionReg.m  ex2data2.txt  plotDecisionBoundary.m
% ex2.m		   lib		 predict.m

% %%
ex2
% Out:
% Plotting data with + indicating (y = 1) examples and o indicating (y = 0) examples.
% ...
% > In legendHGUsingMATLABClasses>set_children_and_strings (line 650)
%   In legendHGUsingMATLABClasses>make_legend (line 313)
%   In legendHGUsingMATLABClasses (line 241)
%   In legend (line 118)
%   In ex2 (line 45)]
%
% Program paused. Press enter to continue.
% Cost at initial theta (zeros): 0.000000
% Gradient at initial theta (zeros):
%  0.000000
%  0.000000
%  0.000000
%
% Program paused. Press enter to continue.
%
% Initial point is a local minimum.
%
% Optimization completed because the size of the gradient at the initial point
% is less than the default value of the function tolerance.
%
%
%
% Cost at theta found by fminunc: 0.000000
% theta:
%  0.000000
%  0.000000
%  0.000000
% ...
% > In legendHGUsingMATLABClasses>set_children_and_strings (line 650)
%   In legendHGUsingMATLABClasses>make_legend (line 313)
%   In legendHGUsingMATLABClasses (line 241)
%   In legend (line 118)
% ...

% %%
mean(X(:,2))
% Out:
% ans =
%
%    65.6443

% %%
mean(X(:,3))
% Out:
% ans =
%
%    66.2220

% %%
X(1,2)
% Out:
% ans =
%
%    34.6237

% %%
data
% Out:
% data =
%
%    34.6237   78.0247         0
%    30.2867   43.8950         0
%    35.8474   72.9022         0
%    60.1826   86.3086    1.0000
%    79.0327   75.3444    1.0000
%    45.0833   56.3164         0
%    61.1067   96.5114    1.0000
%    75.0247   46.5540    1.0000
%    76.0988   87.4206    1.0000
%    84.4328   43.5334    1.0000
%    95.8616   38.2253         0
%    75.0137   30.6033         0
%    82.3071   76.4820    1.0000
%    69.3646   97.7187    1.0000
%    39.5383   76.0368         0
%    53.9711   89.2074    1.0000
%    69.0701   52.7405    1.0000
%    67.9469   46.6786         0
%    70.6615   92.9271    1.0000
%    76.9788   47.5760    1.0000
%    67.3720   42.8384         0
%    89.6768   65.7994    1.0000
%    50.5348   48.8558         0
%    34.2121   44.2095         0
%    77.9241   68.9724    1.0000
%    62.2710   69.9545    1.0000
%    80.1902   44.8216    1.0000
%    93.1144   38.8007         0
%    61.8302   50.2561         0
% ...

% %%
X = data(:, [1, 2]); y = data(:, 3);

% %%
X
% Out:
% X =
%
%    34.6237   78.0247
%    30.2867   43.8950
%    35.8474   72.9022
%    60.1826   86.3086
%    79.0327   75.3444
%    45.0833   56.3164
%    61.1067   96.5114
%    75.0247   46.5540
%    76.0988   87.4206
%    84.4328   43.5334
%    95.8616   38.2253
%    75.0137   30.6033
%    82.3071   76.4820
%    69.3646   97.7187
%    39.5383   76.0368
%    53.9711   89.2074
%    69.0701   52.7405
%    67.9469   46.6786
%    70.6615   92.9271
%    76.9788   47.5760
%    67.3720   42.8384
%    89.6768   65.7994
%    50.5348   48.8558
%    34.2121   44.2095
%    77.9241   68.9724
%    62.2710   69.9545
%    80.1902   44.8216
%    93.1144   38.8007
%    61.8302   50.2561
%    38.7858   64.9957
%    61.3793   72.8079
%    85.4045   57.0520
%    52.1080   63.1276
%    52.0454   69.4329
%    40.2369   71.1677
%    54.6351   52.2139
%    33.9155   98.8694
%    64.1770   80.9081
%    74.7893   41.5734
%    34.1836   75.2377
%    83.9024   56.3080
%    51.5477   46.8563
%    94.4434   65.5689
% ...

% %%
X(1,1)
% Out:
% ans =
%
%    34.6237

% %%
ex2
% Out:
% Plotting data with + indicating (y = 1) examples and o indicating (y = 0) examples.
%
% Program paused. Press enter to continue.
% Cost at initial theta (zeros): 0.000000
% Gradient at initial theta (zeros):
%  0.000000
%  0.000000
%  0.000000
%
% Program paused. Press enter to continue.
%
% Initial point is a local minimum.
%
% Optimization completed because the size of the gradient at the initial point
% is less than the default value of the function tolerance.
%
%
%
% Cost at theta found by fminunc: 0.000000
% theta:
%  0.000000
%  0.000000
%  0.000000
%
% Program paused. Press enter to continue.
% For a student with scores 45 and 85, we predict an admission probability of 0.000000
%
% Train Accuracy: 40.000000
%
% Program paused. Press enter to continue.

% %%
mat = [1 2 3 4 5 6]
% Out:
% mat =
%
%      1     2     3     4     5     6

% %%
sigmoid(mat')
% Out:
% g =
%
%     0.7311         0         0         0         0         0
%
%
% ans =
%
%     0.7311         0         0         0         0         0

% %%
1 / (1 + exp(-0))
% Out:
% ans =
%
%     0.5000

% %%
rand(3,3)
% Out:
% ans =
%
%     0.8147    0.9134    0.2785
%     0.9058    0.6324    0.5469
%     0.1270    0.0975    0.9575

% %%
matt = rand(3,3)
% Out:
% matt =
%
%     0.9649    0.9572    0.1419
%     0.1576    0.4854    0.4218
%     0.9706    0.8003    0.9157

% %%
pp = zeros(size(matt)); 
1 / (1 + exp(-matt))
% Out:
% Matrix dimensions must agree.

% %%
sigmoid(matt')
% Out:
% File /Users/tarek_allam/coursera/MachineLearning-Stanford/machine-learning-ex2/ex2/sigmoid.m, line 12, in sigmoid
% Matrix dimensions must agree.
